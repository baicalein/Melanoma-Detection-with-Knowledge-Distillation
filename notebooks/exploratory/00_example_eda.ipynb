# %% [markdown]
# # Example Exploratory Data Analysis
#
# This notebook demonstrates the basic structure for exploratory data analysis.
# Copy this template for your own EDA notebooks.
#
# **Date**: YYYY-MM-DD
# **Author**: Your Name
# **Purpose**: Initial exploration of the dataset

# %% [markdown]
# ## Setup

# %%
# Standard imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# Project imports
from deep_learning_final_project.data import DATA_DIR, RAW_DATA_DIR, PROCESSED_DATA_DIR

# Set random seed for reproducibility
np.random.seed(42)

# Configure plotting
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")
# %matplotlib inline

# Display settings
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# %% [markdown]
# ## 1. Load Data

# %%
# Example: Load your dataset
# df = pd.read_csv(RAW_DATA_DIR / "dataset.csv")
# print(f"Dataset shape: {df.shape}")
# df.head()

# %% [markdown]
# ## 2. Basic Statistics

# %%
# Example: Basic statistics
# print("Dataset Info:")
# df.info()
# 
# print("\nSummary Statistics:")
# df.describe()

# %% [markdown]
# ## 3. Data Quality Checks

# %%
# Example: Check for missing values
# missing = df.isnull().sum()
# print("Missing values per column:")
# print(missing[missing > 0])

# %% [markdown]
# ## 4. Visualizations

# %%
# Example: Distribution plots
# fig, axes = plt.subplots(2, 2, figsize=(12, 10))
# 
# # Add your visualizations here
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## 5. Key Findings
#
# Document your findings here:
#
# - Finding 1: ...
# - Finding 2: ...
# - Finding 3: ...

# %% [markdown]
# ## 6. Next Steps
#
# Based on this analysis, next steps are:
#
# 1. [ ] Task 1
# 2. [ ] Task 2
# 3. [ ] Task 3
